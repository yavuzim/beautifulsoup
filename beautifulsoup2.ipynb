# %% [markdown]
# <a href="https://colab.research.google.com/github/yavuzim/beautifulsoup/blob/main/beautifulsoup2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4 aiohttp fake-useragent
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (3.11.10)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp) (1.18.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from multidict<7.0,>=4.5->aiohttp) (4.12.2)

# %%
import requests
from bs4 import BeautifulSoup
import logging
import time
import random
from typing import Optional, List, Dict, Any
from dataclasses import dataclass
from urllib.parse import urljoin
import concurrent.futures
import aiohttp
import asyncio
import nest_asyncio
from fake_useragent import UserAgent
from requests.adapters import HTTPAdapter

# %%
@dataclass
class ScrapingConfig:
    base_url: str
    headers: Dict[str, str]
    proxies: Optional[Dict[str, str]] = None
    timeout: int = 30
    max_retries: int = 3
    delay_range: tuple = (1, 3)

class WebScraper:
    def __init__(self, config: ScrapingConfig):
        self.config = config
        self.session = self._create_session()
        self.logger = self._setup_logger()
        self.user_agent = UserAgent()

    def _setup_logger(self) -> logging.Logger:
        """Logger yapılandırması"""
        logger = logging.getLogger('WebScraper')
        logger.setLevel(logging.INFO)

        handler = logging.FileHandler('scraping.log')
        handler.setFormatter(
            logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        )
        logger.addHandler(handler)

        return logger

    def _create_session(self) -> requests.Session:
        """Retry mekanizmalı session oluşturma"""
        session = requests.Session()

        retry_strategy = Retry(
            total=self.config.max_retries,
            backoff_factor=0.5,
            status_forcelist=[500, 502, 503, 504]
        )

        adapter = HTTPAdapter(max_retries=retry_strategy)
        session.mount("http://", adapter)
        session.mount("https://", adapter)

        return session

    def _get_headers(self) -> Dict[str, str]:
        """Random User-Agent ile headers oluşturma"""
        headers = self.config.headers.copy()
        headers['User-Agent'] = self.user_agent.random
        return headers

    def _random_delay(self):
        """İstekler arası random gecikme"""
        time.sleep(random.uniform(*self.config.delay_range))

    def get_page_content(self, url: str) -> Optional[BeautifulSoup]:
        """Sayfa içeriğini alma ve parse etme"""
        try:
            self._random_delay()

            response = self.session.get(
                url,
                headers=self._get_headers(),
                proxies=self.config.proxies,
                timeout=self.config.timeout
            )
            response.raise_for_status()

            return BeautifulSoup(response.content, 'html.parser')

        except Exception as e:
            self.logger.error(f"Error fetching {url}: {str(e)}")
            return None

    async def async_get_page(self, url: str) -> Optional[str]:
        """Asenkron sayfa içeriği alma"""
        try:
            async with aiohttp.ClientSession() as session:
                async with session.get(
                    url,
                    headers=self._get_headers(),
                ) as response:
                    return await response.text()

        except Exception as e:
            self.logger.error(f"Error in async fetch {url}: {str(e)}")
            return None

    def parse_content(self, soup: BeautifulSoup, selectors: Dict[str, str]) -> Dict[str, Any]:
        """İçerik parse etme"""
        result = {}

        for key, selector in selectors.items():
            try:
                element = soup.select_one(selector)
                if element:
                    result[key] = element.get_text(strip=True)
                else:
                    result[key] = None
                    self.logger.warning(f"Selector '{selector}' not found for key '{key}'")

            except Exception as e:
                self.logger.error(f"Error parsing {key}: {str(e)}")
                result[key] = None

        return result

    def scrape_multiple_pages(self, urls: List[str], selectors: Dict[str, str]) -> List[Dict[str, Any]]:
        """Çoklu sayfa scraping"""
        results = []

        with concurrent.futures.ThreadPoolExecutor() as executor:
            future_to_url = {
                executor.submit(self.get_page_content, url): url
                for url in urls
            }

            for future in concurrent.futures.as_completed(future_to_url):
                url = future_to_url[future]
                try:
                    soup = future.result()
                    if soup:
                        data = self.parse_content(soup, selectors)
                        data['url'] = url
                        results.append(data)

                except Exception as e:
                    self.logger.error(f"Error processing {url}: {str(e)}")

        return results

    async def async_scrape_multiple_pages(self, urls: List[str], selectors: Dict[str, str]) -> List[Dict[str, Any]]:
        """Asenkron çoklu sayfa scraping"""
        tasks = [self.async_get_page(url) for url in urls]
        pages = await asyncio.gather(*tasks)

        results = []
        for url, html in zip(urls, pages):
            if html:
                soup = BeautifulSoup(html, 'html.parser')
                data = self.parse_content(soup, selectors)
                data['url'] = url
                results.append(data)

        return results

# %%
# Asenkron çoklu scraping
async def main():
    results = await scraper.async_scrape_multiple_pages(urls, selectors)
    await asyncio.run(main())

if __name__ == "__main__":
    config = ScrapingConfig(
        base_url="https://example.com",
        headers={
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'en-US,en;q=0.5',
        }
    )

    scraper = WebScraper(config)
    number = 1

    # Tek sayfa scraping
    url = "https://www.dunyahalleri.com/category/teknoloji-bilim/page/"+str(number)

    selectors = {
        'gundem': 'div[class*="taxonomy-category"] a',
        'baslik': 'h2.wp-block-post-title',
        'ozet': 'div[class*="wp-block-post-excerpt"] p'
    }

    soup = scraper.get_page_content(url)
    if soup:
        # İçeriği parse et
        # Verilerin tümünü çekmek için döngü ekliyoruz
        data = []
        gundem_elements = soup.select(selectors['gundem'])
        baslik_elements = soup.select(selectors['baslik'])
        ozet_elements = soup.select(selectors['ozet'])

        for gundem, baslik, ozet in zip(gundem_elements, baslik_elements, ozet_elements):
            data.append({
                'gundem': gundem.text.strip(),
                'baslik': baslik.text.strip(),
                'ozet': ozet.text.strip()
            })

        print("data : ", data)

    # Çoklu sayfa scraping
    urls = [
       "https://www.dunyahalleri.com/category/haftanin-ozeti/page/"+str(number),
            "https://www.dunyahalleri.com/category/genel-gundem/page/"+str(number),
            "https://www.dunyahalleri.com/category/teknoloji-bilim/page/"+str(number),
            "https://www.dunyahalleri.com/category/internet-girisimler/page/"+str(number),
            "https://www.dunyahalleri.com/category/tasarim-inovasyon/page/"+str(number),
            "https://www.dunyahalleri.com/category/kultur-sanat/page/"+str(number)
    ]
    # Senkron çoklu scraping

    for url in urls:
      print("url : ",url)
      soup = scraper.get_page_content(url)
      # print(soup)
      if soup:
        results = []
        gundem_elements = soup.select(selectors['gundem'])
        baslik_elements = soup.select(selectors['baslik'])
        ozet_elements = soup.select(selectors['ozet'])
        gundem_count = len(gundem_elements)
        print(f"gundem öğeleri sayısı: {gundem_count}")
        for gundem, baslik, ozet in zip(gundem_elements, baslik_elements, ozet_elements):
          results.append({
              'gundem': gundem.text.strip(),
              'baslik': baslik.text.strip(),
              'ozet': ozet.text.strip()
          })


        print("->>> ",results)
# Out:
# data :  [{'gundem': 'Teknoloji / Bilim', 'baslik': 'Yapay zeka, işlevini kaybedecek böbreği iki gün önceden belirleyebiliyor', 'ozet': 'DeepMind adlı yapay zeka şirketi, akut böbrek yetmezliğini 48 saat önceden tahmin edebilen bir yapay zeka sistemi üzerinde çalışıyor.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Hoverboard’la Manş Denizi’ni geçme denemesi tekrarlanacak', 'ozet': 'Geçen hafta hoverboard üzerinde Manş Denizi’ni geçmeye çalışıp başarısız olan Franky Zapata, şansını bir kez daha deneyecek.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': '
ek.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Capital One bankası 106 milyon müşterisinin verilerini çaldırdı', 'ozet': 'ABD’nin en büyük bankalarından Capital One, 22-23 Mart tarihlerinde bankada büyük çaplı bir veri ihlali yaşandığını açıkladı.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Fransa uydularına lazerli savunma sistemleri yerleştirmek istiyor', 'ozet': 'Uzay lazerlerini öz savunma amaçlı kullanmak istediğini açıklayan Fransa, uydularına silah ve lazerler ekleyecek.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Modern toplumda cinsiyet rolleri çocukların çizimleriyle ele alındı', 'ozet': 'Almanya’da yapılan araştırmalar, çocukların cinsiyet rollerine yönelik algısının geçmişe göre daha eşitlikçi olduğunu gösteriyor.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Yeni keşfedilen hücre ile karaciğer nakli tarihe karışabilir', 'ozet': 'King’s College London’da çalışan araştırmacılar, yeni bir tür hücre keşfetti. Bu gelişme, karaciğer naklini rafa kaldırabilecek nitelikte.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'No More Ransom projesi 108 milyon Dolar’ın hacker’lara gitmesini engelledi', 'ozet': 'Şifreleme yazılımlarından zarar görmüş dosyaları çözmede kullanılan araçlar sunan bir proje, 108 milyon Dolar’ın hacker’lara gitmesine engel oldu.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Yapay zekanın yazdığı sahte metinleri anlayabilen yapay zeka', 'ozet': 'Sahte haber ve resimlere karşı verilen savaşta güçlü bir silah görevi görebilecek yeni bir yapay zeka aracı geliştirildi.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'CRISPR, körlüğü tedavi etmek için ilk kez vücut içinde kullanılacak', 'ozet': 'İki şirket, gen düzenleme tekniği CRISPR’ı kullanarak kalıtım yoluyla geçen bir geni değiştirecek.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Ay görevinden dönen astronotların gümrük belgesi', 'ozet': 'Apollo 11 astronotları, Ay’dan döndükten sonra bir gümrük belgesi imzalamışlar.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Yapay boğaz konuşma engelliler için çözüm olabilir', 'ozet': 'Bir grup Çinli araştırmacı, geçici bir dövme gibi boğaza takılabilen giyilebilir yapay gırtlak geliştirdi.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Samsung Galaxy Fold’u Eylül’de satışa sunacak', 'ozet': 'Tasarımıyla ilgili birkaç değişiklik yapılan katlanabilir telefon Galaxy Fold, Eylül ayında satışa sunulacak.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Yazılıma kasten hata ekleyen yazılımcı', 'ozet': 'Çalıştığı şirketin sistemine yazılım bombaları yerleştiren David Tinley, hapis ve yüklü miktarda para cezasıyla karşı karşıya.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Ay’da düşündüğümüzden daha fazla su olabilir', 'ozet': 'Kaliforniya Üniversitesi araştırmacıları, Ay’da sandığımızdan daha fazla su olduğuna işaret eden bir araştırma gerçekleştirdi.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'iPhone 4S ve öncesinde üretilen Apple cihazlar için iOS güncellemesi kullanıma sunuldu', 'ozet': 'Apple, bazı ürünlerinin GPS zaman yenileme sorunundan etkilenmemesi adına eski cihazları için iOS güncellemesi sunuyor.'}]
# url :  https://www.dunyahalleri.com/category/internet-girisimler/page/1
# gundem öğeleri sayısı: 16
# ->>>  [{'gundem': 'İnternet / Girişimler', 'baslik': 'YouTube, kaliteli aile dostu içerikleri öne çıkarmak için algoritmasını değiştirdi', 'ozet': 'Bloomberg’in haberine göre YouTube, Temmuz ayında algoritmasında sessiz sedasız değişiklikler yaptı. Bu değişiklikler birkaç YouTube kanalının görüntülenme sayısında ciddi bir azalmaya sebep oldu. YouTube sözcülerinden…'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Alphabet, Apple’ı geçerek dünyanın en fazla nakit bulunduran şirketi oldu', 'ozet': 'Google’ın ana şirketi Alphabet, nakit açısından en zengin şirket olma unvanını kazanarak Apple’ın tacını elinden aldı.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Genç görünmek için filtre kullanan Çinli vlogger’ın foyası ortaya çıktı', 'ozet': 'Bir gazete haberinde “hayranlarının bağış yaptığı sevimli tanrıça” diye bahsedilen vlogger’ın genç görünmek için filtre kullanan orta yaşlı biri olduğu anlaşıldı.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Netflix ve YouTube Tesla otomobillerde kullanılabilecek', 'ozet': 'Elon Musk, yakında Tesla araçlarda Netflix ve YouTube’dan video seyredilebileceğini Twitter üzerinden duyurdu.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Otomatik oynayan videoları ve sonsuz kaydırmayı yasaklamak için yasa teklifi sunuldu', 'ozet': 'Kullanıcıyı uygulamaya ‘bağımlı’ hale getiren tasarım özelliklerini hedef alan yeni bir yasa tasarısı sunuldu.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'No More Ransom projesi 108 milyon Dolar’ın hacker’lara gitmesini engelledi', 'ozet': 'Şifreleme yazılımlarından zarar görmüş dosyaları çözmede kullanılan araçlar sunan bir proje, 108 milyon Dolar’ın hacker’lara gitmesine engel oldu.'}, {'gundem': 'Teknoloji / Bilim', 'baslik': 'Tiktok’un sahibi ByteDance akıllı telefon üretecek', 'ozet': 'TikTok’un ana şirketi ByteDance, Baidu ve Tencent gibi dev isimlerle girdiği yarışta fark yaratabilmek için akıllı telefon üretecek.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Fortnite hakkında sormaya çekindiğiniz her şey', 'ozet': 'Ana başlıklarla, Fornite’a dair bilmek istediğiniz ama gençlerle konuşmaya çekindiğiniz her şeyin bir derlemesi.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Güney Kore’de 6 yaşındaki YouTuber 8 milyon Dolar değerinde ev aldı', 'ozet': 'Toplamda 30 milyondan fazla aboneye sahip Boram adlı çocuk YouTube yıldızı, 8 milyon Dolar’lık ev satın aldı.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Apple, Intel’in modem bölümünü satın alacak', 'ozet': '25 Temmuz’da bir basın açıklaması yayımlayan Apple, Intel’in akıllı telefon modem bölümünü satın alacağını duyurdu.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Gürültülü ortamlarda duyma gücünüzü artıran uygulama', 'ozet': 'Google’ın Sound Amplifier adlı Android uygulaması, gürültülü yerlerde duyma gücünüzü artırıyor.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Tinder kullanıcılarını LGBTQ’nun yasa dışı olduğu ülkelerde uyaracak', 'ozet': 'Tinder, LGBTQ’nun yasak olduğu ülkelere seyahat eden kullanıcılarının profilini otomatik olarak gizleyerek uyarı mesajı gönderecek.'}, {'gundem': 'İnternet / Girişimler', 'baslik': '“İnternetten tanışmak” artık ilişkiler için en popüler başlangıç şekli', 'ozet': 'Bir sosyolog tarafından yapılan araştırma, 2009-2017 yılları arasında heteroseksüel çiftlerin yüzde 40’ının internetten tanıştığını gösteriyor.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Hedeflerine ulaşamayan Netflix’in hisseleri değer kaybetti', 'ozet': 'Netflix, yapımların tahmin edildiği kadar beğenilmemesi ve fiyat artışı gibi sebeplerle müşteri kaybetti.'}, {'gundem': 'İnternet / Girişimler', 'baslik': 'Juventus’un isim haklarını kaybeden EA, 750 milyon Dolar zarar etti', 'ozet': 'Juventus ile isim anlaşması sona eren EA, FIFA 2020’de Torino ekibinin ismini Piemonte Calcio olarak kullanacak.'}]
# url :  https://www.dunyahalleri.com/category/tasarim-inovasyon/page/1
# gundem öğeleri sayısı: 15
# ->>>  [{'gundem': 'Tasarım / İnovasyon', 'baslik': 'Dizel araçları elektrikliye dönüştüren girişim', 'ozet': 'Transition-One adlı girişim, donanım iyileştirme teknolojisiyle eski dizel araçları elektrikli araca dönüştürüyor.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Magnet kullanarak suyu mikroplastiklerden temizleyen genç', 'ozet': 'İrlandalı bir genç, sudaki mikroplastikleri temizlemek için sıvı mıknatıs kullandığı bir proje geliştirdi ve Google Bilim Fuarı’nda birinci oldu.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Arılara özel pizza: Beezza', 'ozet': 'Biyoçeşitliliğe dikkat çekmek için, yaban arılarına özel minyatür pizzalara üretildi.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Hamam böceğinden daha hızlı hareket edebilen minik robot', 'ozet': 'Kendi ağırlığının bin kat fazlası uygulandığında bile hareket etmeye devam eden yumuşak robot geliştirildi.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Impossible Burger Amerikan Gıda ve İlaç Dairesi’nden onay aldı', 'ozet': 'Sonbahar itibariyle ABD’deki marketlerde yapay et satılmaya başlanacak.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Elektrikli aracına güneş paneli ekleyen adam', 'ozet': 'Güneş enerjili Nissan LEAF projesi, güneş enerjisiyle çalışan elektrikli araçların potansiyeline dikkat çekiyor.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Facebook, artırılmış gerçeklik için beyin implantları üzerinde çalışıyor', 'ozet': 'Facebook, klavye kullanmadan beyin gücümüzle yazı yazmamızı sağlayacak bir cihaz üzerinde çalışıyor.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Bitki tabanlı yumurta satışa sunuldu', 'ozet': 'Kanada’daki bir fast food zinciri, bazı şubelerinde maş fasulyesinden üretilen vegan yumurtayla yapılmış yiyecekler sunuyor.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Göz kırpınca zum yapan robotik lensler', 'ozet': 'Gözün doğal yapısını taklit etme mantığıyla çalışan, iki kez göz kırpınca yakınlaştırma ya da uzaklaştırma yapabilen robotik lens geliştirildi.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Hızyuvar Riyad-Cidde arasını 76 dakikaya indirecek', 'ozet': 'Hızyuvar teknolojisi, normalde 10 saatten fazla süren Riyad-Cidde arası yolu 76 dakikaya indirme iddiasına sahip.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Sony’nin giyilebilir kliması', 'ozet': 'Özel olarak üretilen bir tişörtün arka kısmındaki cebe yerleştirilen Reon Pocket adlı giyilebilir klima, vücudu 13 derece soğutabiliyor.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Teknolojik kahve sehpası', 'ozet': 'Kablosuz şarj özelliği, mini buzdolabı ve Google Home akıllı ev asistanı barındıran teknolojik bir sehpa geliştiriliyor.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Lego parçalarıyla Buzz Aldrin’in gerçek boyutlu modeli yapıldı', 'ozet': 'Apollo 11 uzay aracının Ay’a inişinin 50. yıl dönümü şerefine lego parçaları kullanılarak Buzz Aldrin’in gerçek boyutlu modeli yapıldı.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Havayolu şirketleri orta koltuk tasarımını değiştiriyor', 'ozet': 'Uçak yolculuklarında orta koltukta oturan kişinin konforunu artırmak amacıyla yeni bir uçak koltuğu geliştirildi.'}, {'gundem': 'Tasarım / İnovasyon', 'baslik': 'Birleşerek tek bir robota dönüşebilen modüler robotlar', 'ozet': 'Araştırmacılar, daha büyük ve daha karmaşık büyük bir robot oluşturabilen küçük modüler robotlar geliştirdi.'}]
# url :  https://www.dunyahalleri.com/category/kultur-sanat/page/1
# gundem öğeleri sayısı: 15
# ->>>  [{'gundem': 'Kültür / Sanat', 'baslik': 'Ed Sheeran’ın turnesi U2’nun rekorunu kıracak', 'ozet': '28 yaşındaki genç şarkıcı Ed Sheeran, 2017’nin Mart ayından beri süren Divide adlı turnesi sayesinde rekor kıracak.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Tesla’nın ‘köpek modu’ arızası düzeltildi', 'ozet': 'Bir Tesla kullanıcısının bildirdiği köpek modu arızası üzerine şirket, hızlı şekilde yazılım güncellemesi yaptı.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Lollapalooza festivali Youtube’dan canlı yayınlanıyor', 'ozet': '1991’den beri yapılan Lollapalooza Müzik Festivali bu yıl YouTube’dan canlı yayınlanıyor.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Mahkeme Katy Perry’nin Dark Horse şarkısının çalıntı olduğuna karar verdi', 'ozet': 'Kaliforniya jürisi, pop şarkıcısı Katy Perry’nin Dark Horse parçasının çalıntı olduğuna karar verdi.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'iPhone fotoğrafçılık ödülleri', 'ozet': 'Bu yıl 12.si düzenlenen iPhone Fotoğrafçılık Ödülleri’nde büyük ödülü kazanan fotoğraf, Zanzibar’da kumsalda çekildi.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'İlişkilerde romantik akşam yemeklerini unutun, doğada geçirilen buluşmalara yer verin', 'ozet': 'Partnerinizle akşam buluşmalarını unutun. Bir terapist, doğada gündüz gerçekleşen buluşmaların etkisine kefil.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'İlk kez Comic-Con’da gösterilen fragmanlar ve tanıtım videoları', 'ozet': 'Geçtiğimiz hafta sonu düzenlenen Comic-Con etkinliğinde birçok yeni film ve dizinin fragmanları yayımlandı.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Satranç ustasının tuvalette telefondan kopya çektiği ortaya çıktı', 'ozet': 'Dünyanın en iyi satranç oyuncuları listesinde 53. sırada yer alan Igors Rausis’in satranç turnuvası esnasında telefonundan kopya çektiği ortaya çıktı.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Scarlett Johansson: “Oyuncular istediği karakteri oynayabilmeli”', 'ozet': 'Tepkiler üzerine trans bir karakteri canlandırmaktan vazgeçen Scarlett Johansson yine de bir oyuncunun her karakteri canlandırabilmesi gerektiğini düşünüyor'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Taş Devri geri dönüyor', 'ozet': 'Taş Devri çizgi filmindeki karakterler kullanılarak yetişkinlere hitap eden bir animasyon televizyon dizisi yapılacak.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Yeni Örümcek Adam filmi beklenenden çok daha fazla kazandı', 'ozet': 'Örümcek Adam: Evden Uzakta filmi, beklentilerin çok üstüne çıkarak şu ana kadar toplamda 580 milyon Dolar kazandı.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Spotify sanatçıların kendi müziklerini yüklemelerine izin vermeyecek', 'ozet': 'Spotifty, sanatçıların bir aracıya ihtiyaç duymadan müzik yüklemesini sağlayan programını 30 Temmuzda’da kapatıyor.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Dünyanın ilk şarap tema parkı Fransa’da açıldı', 'ozet': 'Dünyanın ilk şarap tema parkı La Cité du Vin (Şarap Şehri) Fransa’nın Bordeaux kentinde ziyaretçilerini bekliyor.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Raspberry Pi ile çalışan taşınabilir synthesizer', 'ozet': 'Critter & Guitari’nin en önemli ürünü Organelle’e çeşitli güncellemeler yapılarak Organelle M adıyla piyasaya sürüldü.'}, {'gundem': 'Kültür / Sanat', 'baslik': 'Dünyanın farklı ülkelerinden çocuklar, günlük yemekleri ile fotoğraflandı', 'ozet': 'Fotoğrafçı Gregg Segal, dünyanın çeşitli ülkelerinden çocukları bir hafta boyunca yedikleriyle birlikte fotoğrafladı.'}]
